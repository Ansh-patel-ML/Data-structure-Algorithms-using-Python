# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.next = None


def take_input():

    input_data = [int(element) for element in input().split()]
    head = None
    tail = None

    for curr_data in input_data:

        if curr_data == -1:
            return head
        node = Node(curr_data)

        if head is None:
            head = node
            tail = node
        else:
            tail.next = node
            tail = node
    return head

def Print_LL(head_of_LL):

    while head_of_LL is not None:
        print(str(head_of_LL.data) + ' -> ',end='')
        head_of_LL = head_of_LL.next
    print('None')
    return

def swap_two_nodes(i, j, head_of_ll):
    prev1, curr1 = None, None
    prev2, curr2 = None, None
    tail = head_of_ll
    previous = None
    index = 0
    head = head_of_ll
    while head_of_ll is not None:
        if index is i:
            curr1 = head_of_ll
            prev1 = previous
        if index is j:
            curr2 = head_of_ll
            prev2 = previous

        tail = tail.next
        index += 1
        previous = head_of_ll
        head_of_ll = head_of_ll.next

    if (i == 0 or j == 0) and j - i == 1:
        curr1.next = curr2.next
        curr2.next = curr1
        head = curr2
    elif i == 0 or j == 0:
        temp = curr1.next
        curr1.next = curr2.next
        curr2.next = temp
        prev2.next = curr1
        head = curr2
    elif j - i == 1:
        prev1.next = curr2
        curr1.next = None
        temp = curr2.next
        curr2.next = curr1
        curr1.next = temp
    else:
        prev1.next = curr2
        prev2.next = curr1
        curr1.next = curr2.next
        curr2.next = prev2
    return head

# %%
x = take_input()
Print_LL(x)
y = swap_two_nodes(int(input('Enter i')), int(input('Enter j')), x)
Print_LL(y)
# Out:
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> None
# 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 -> 1 -> 4 -> 3 -> 2 ->  ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/x2/lrf09j9528x27kg9knf4rhnm0000gp/T/ipykernel_78100/3006936974.py in <module>
#       2 Print_LL(x)
#       3 y = swap_two_nodes(int(input('Enter i')), int(input('Enter j')), x)
# ----> 4 Print_LL(y)
#
# /var/folders/x2/lrf09j9528x27kg9knf4rhnm0000gp/T/ipykernel_78100/1121442660.py in Print_LL(head_of_LL)
#      29
#      30     while head_of_LL is not None:
# ---> 31         print(str(head_of_LL.data) + ' -> ',end='')
#      32         head_of_LL = head_of_LL.next
#      33     print('None')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/iostream.py in write(self, string)
#     517             is_child = (not self._is_master_process())
#     518             # only touch the buffer in the IO thread to avoid races
# --> 519             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     520             if is_child:
#     521                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
